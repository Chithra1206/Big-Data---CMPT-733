# %%
import findspark
findspark.init('C:\spark\spark-2.2.1-bin-hadoop2.7')

import pandas as pd

from pyspark import SparkContext
from pyspark.sql import SparkSession

from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

import gensim
from gensim import corpora

import os

import json
# Out:
# C:\Users\LunaS\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
sc = SparkContext().getOrCreate()
spark = SparkSession.builder.appName('comment topic modeling').getOrCreate()

# %% [markdown]
# ### read data

# %%
article_ids = []
 = []
for folder in os.listdir('comments_groupby_article'):
    article_id = folder.split('_')[2]
    inputloc = "comments_groupby_article/" + folder + "/*.csv" 
    df = spark.read.csv(inputloc, header="true")
    comment_text = df.select("comment_text").rdd.flatMap(lambda x: x).collect()
    comment_texts.append(comment_text)
    article_ids.append(article_id)
# Out:
# Wall time: 0 ns

# %%
comment_df = pd.DataFrame({'article_ids':article_ids,'comment_texts':comment_texts})
comment_df
# Out:
#      article_ids                                      comment_texts
# 0       10030963  [My 2 cents: fire every single last one of the...
# 1       10108172  [Stephen Harper is destroying Canada's interna...
# 2       10193881  ['Gay marriage is a non-issue in Canada, but i...
# 3       10198519  [It isn't hard to govern a country with people...
# 4       10199024  [This says more about the so called discrimina...
# 5       10200251  [This openness is a credit to the Globe. For d...
# 6       10508775  [What is good about good Friday? Inherently no...
# 7       10527549  [Ms. Wente is making many assumptions here. In...
# 8       10549743  [Ken, don't project your inferiority complex u...
# 9       10556177  [Excuse me but... don't you think you could go...
# 10      10586347  [What a jack**s. Stop pushing your Chicago Sch...
# 11      10600939  [The UN happens to be the best body in which t...
# 12      10645044  [I am not a big fan of the UN and certainly ha...
# 13      10674115  [Justin Trudeau doen't just shake his kids han...
# 14      10713368  [Barbaric? it sounds like suggestive and descr...
# 15      10749814  [So far in Canada, we have been able to avoid ...
# 16      10762639  [Interesting that the author mentions Seoul, S...
# 17      10763895  [Why the Globe needs to discard its poisoned e...
# 18      10791308  [We have to get the Aboriginals out of those r...
# 19      10798463  [Climate change is happening now. The major re...
# 20      10809725  [Thanks to Mr Fraser for expressing an articul...
# 21      10813439  [I was at university in the 80's & 90's - marr...
# 22      10841311  [For the better? Here is a better heading. WHY...
# 23      10869374  [i first left university in 1979, and back the...
# 24      10869396  [The Harper Regime does not reflect the views ...
# 25      10915088  [Thatcher supported Pol Pot with state forces ...
# 26      10932004  [This doesn't even feel like a country any mor...
# 27      10934025  [Given the 1,000,000+ miles I have flown in my...
# 28      10947253  [Simpson trivializes the significant contribut...
# 29      11017537  [Atlantic City. Windsor. Niagara Falls. What g...
# ...          ...                                                ...
# 2153     9017719  [OMG is Ibbitson showing his heroworship doer ...
# 2154     9046904  [Another left-wing socialist propaganda piece ...
# 2155     9049909  [The problem today is hi-bred corn, white brea...
# 2156     9088546  [Bravo Mr. Simpson!, The Conservatives have al...
# 2157     9129832  [Labour is not just a market. Workers are Cana...
# 2158     9174532  [Taxes went up, Obama keeps lying about that.,...
# 2159     9175062  [GO BACK TO NORTH KOREA IF YOU WANT TO WRITE P...
# 2160     9234617  [Just a reminder. Pensions are long term. Surp...
# 2161     9255841  [A note to the author of this opinion piece: M...
# 2162     9296018  [Why is it so hard to find water in any gov. b...
# 2163     9317535  [I know physically healthy people who see thei...
# 2164     9336246  [What ever Chavez faults. Judging by the thous...
# 2165     9397380  [Don't you guys know your statistics? Or do yo...
# 2166     9468281  [The opposition is less divided than it was du...
# 2167     9532037  [Well said - couldn't agree more with this art...
# 2168     9552917  [Thank you Mr. Saunders, greetings from Panam?...
# 2169     9552951  [The Government spends more money per citizen ...
# 2170     9602111  [Just one question for you catholics ... if yo...
# 2171     9607193  [Well we might add Jack very risky frienemies ...
# 2172     9623584  [I own a condo in BC, can I get a carbon credi...
# 2173     9623677  [Harper is in serious trouble--the numerous sc...
# 2174     9707992  [Obama is a great President equal to Lincoln a...
# 2175     9750414  [Failing? Failing whom, Margaret? No topic has...
# 2176     9781647  [His withdrawal simply shows that the Party di...
# 2177     9869958  [Woman dress provocatively, end up inebriated ...
# 2178     9934348  [Oh shut up., Six pages of comments about some...
# 2179     9939885  [Actually, the opposition parties have a much ...
# 2180     9942689  [Bad weather, high taxes, fascist government i...
# 2181     9943718  [Agree with the writer that the holocaust has ...
# 2182     9965530  [What is more scary than this that a 'well-inf...
#
# [2183 rows x 2 columns]

# %% [markdown]
# ### Build LDA model

# %%
# convert comment_texts type: list -> string
comment_df['comment_texts'] = comment_df['comment_texts'].apply(lambda x: ', '.join(x))
comment_df
# Out:
#      article_ids                                      comment_texts
# 0       10030963  My 2 cents: fire every single last one of them...
# 1       10108172  Stephen Harper is destroying Canada's internat...
# 2       10193881  'Gay marriage is a non-issue in Canada, but it...
# 3       10198519  It isn't hard to govern a country with people ...
# 4       10199024  This says more about the so called discriminat...
# 5       10200251  This openness is a credit to the Globe. For de...
# 6       10508775  What is good about good Friday? Inherently not...
# 7       10527549  Ms. Wente is making many assumptions here. In ...
# 8       10549743  Ken, don't project your inferiority complex up...
# 9       10556177  Excuse me but... don't you think you could go ...
# 10      10586347  What a jack**s. Stop pushing your Chicago Scho...
# 11      10600939  The UN happens to be the best body in which to...
# 12      10645044  I am not a big fan of the UN and certainly hat...
# 13      10674115  Justin Trudeau doen't just shake his kids hand...
# 14      10713368  Barbaric? it sounds like suggestive and descri...
# 15      10749814  So far in Canada, we have been able to avoid t...
# 16      10762639  Interesting that the author mentions Seoul, St...
# 17      10763895  Why the Globe needs to discard its poisoned ed...
# 18      10791308  We have to get the Aboriginals out of those re...
# 19      10798463  Climate change is happening now. The major rei...
# 20      10809725  Thanks to Mr Fraser for expressing an articula...
# 21      10813439  I was at university in the 80's & 90's - marri...
# 22      10841311  For the better? Here is a better heading. WHY ...
# 23      10869374  i first left university in 1979, and back then...
# 24      10869396  The Harper Regime does not reflect the views a...
# 25      10915088  Thatcher supported Pol Pot with state forces a...
# 26      10932004  This doesn't even feel like a country any more...
# 27      10934025  Given the 1,000,000+ miles I have flown in my ...
# 28      10947253  Simpson trivializes the significant contributi...
# 29      11017537  Atlantic City. Windsor. Niagara Falls. What gr...
# ...          ...                                                ...
# 2153     9017719  OMG is Ibbitson showing his heroworship doer o...
# 2154     9046904  Another left-wing socialist propaganda piece o...
# 2155     9049909  The problem today is hi-bred corn, white bread...
# 2156     9088546  Bravo Mr. Simpson!, The Conservatives have alw...
# 2157     9129832  Labour is not just a market. Workers are Canad...
# 2158     9174532  Taxes went up, Obama keeps lying about that., ...
# 2159     9175062  GO BACK TO NORTH KOREA IF YOU WANT TO WRITE PR...
# 2160     9234617  Just a reminder. Pensions are long term. Surpl...
# 2161     9255841  A note to the author of this opinion piece: Ma...
# 2162     9296018  Why is it so hard to find water in any gov. bu...
# 2163     9317535  I know physically healthy people who see their...
# 2164     9336246  What ever Chavez faults. Judging by the thousa...
# 2165     9397380  Don't you guys know your statistics? Or do you...
# 2166     9468281  The opposition is less divided than it was dur...
# 2167     9532037  Well said - couldn't agree more with this arti...
# 2168     9552917  Thank you Mr. Saunders, greetings from Panam?,...
# 2169     9552951  The Government spends more money per citizen t...
# 2170     9602111  Just one question for you catholics ... if you...
# 2171     9607193  Well we might add Jack very risky frienemies t...
# 2172     9623584  I own a condo in BC, can I get a carbon credit...
# 2173     9623677  Harper is in serious trouble--the numerous sca...
# 2174     9707992  Obama is a great President equal to Lincoln an...
# 2175     9750414  Failing? Failing whom, Margaret? No topic has ...
# 2176     9781647  His withdrawal simply shows that the Party dis...
# 2177     9869958  Woman dress provocatively, end up inebriated a...
# 2178     9934348  Oh shut up., Six pages of comments about someo...
# 2179     9939885  Actually, the opposition parties have a much s...
# 2180     9942689  Bad weather, high taxes, fascist government in...
# 2181     9943718  Agree with the writer that the holocaust has b...
# 2182     9965530  What is more scary than this that a 'well-info...
#
# [2183 rows x 2 columns]

# %%
doc_complete = comment_df['comment_texts'].tolist()

# %%
# clean text
stop = set(stopwords.words('english'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

doc_clean = [clean(doc).split() for doc in doc_complete]

# %%
# Creating the term dictionary of our courpus, where every unique term is assigned an index. dictionary = corpora.Dictionary(doc_clean)
dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=10, id2word = dictionary, passes=50)

# %%
# show comments topics
topics = ldamodel.show_topics()
for topic in topics:
    print(str(topic)+'\n')
# Out:
# (0, '0.010*"people" + 0.008*"woman" + 0.006*"one" + 0.006*"would" + 0.006*"nation" + 0.005*"first" + 0.005*"native" + 0.005*"like" + 0.005*"get" + 0.004*"right"')
#
# (1, '0.014*"harper" + 0.009*"liberal" + 0.008*"party" + 0.008*"government" + 0.007*"would" + 0.007*"conservative" + 0.007*"canada" + 0.006*"canadian" + 0.006*"one" + 0.005*"like"')
#
# (2, '0.012*"military" + 0.011*"canada" + 0.011*"war" + 0.007*"combat" + 0.007*"u" + 0.005*"canadian" + 0.005*"soldier" + 0.005*"fighter" + 0.005*"would" + 0.004*"air"')
#
# (3, '0.011*"people" + 0.006*"gun" + 0.006*"would" + 0.006*"food" + 0.006*"drug" + 0.006*"police" + 0.005*"one" + 0.004*"u" + 0.004*"health" + 0.004*"like"')
#
# (4, '0.010*"oil" + 0.008*"canada" + 0.007*"alberta" + 0.006*"would" + 0.005*"people" + 0.005*"u" + 0.005*"government" + 0.004*"pipeline" + 0.004*"like" + 0.004*"canadian"')
#
# (5, '0.012*"tax" + 0.008*"year" + 0.006*"climate" + 0.006*"u" + 0.005*"would" + 0.005*"government" + 0.005*"one" + 0.005*"change" + 0.004*"canada" + 0.004*"income"')
#
# (6, '0.010*"wind" + 0.009*"ontario" + 0.007*"power" + 0.007*"energy" + 0.005*"bear" + 0.005*"one" + 0.004*"year" + 0.004*"green" + 0.004*"nuclear" + 0.004*"turbine"')
#
# (7, '0.014*"trump" + 0.008*"people" + 0.007*"u" + 0.006*"like" + 0.005*"one" + 0.005*"would" + 0.005*"american" + 0.004*"right" + 0.004*"medium" + 0.004*"get"')
#
# (8, '0.007*"job" + 0.007*"school" + 0.007*"people" + 0.006*"get" + 0.006*"work" + 0.006*"one" + 0.006*"would" + 0.006*"teacher" + 0.006*"year" + 0.005*"public"')
#
# (9, '0.008*"people" + 0.006*"right" + 0.006*"would" + 0.006*"one" + 0.006*"canada" + 0.006*"canadian" + 0.005*"country" + 0.004*"like" + 0.004*"u" + 0.004*"law"')

# %%
ldamodel[doc_term_matrix[89]]
# Out:
# [(0, 0.016908653),
#  (1, 0.04636028),
#  (4, 0.07732401),
#  (5, 0.64408153),
#  (7, 0.035113778),
#  (8, 0.16354014),
#  (9, 0.016613139)]

# %% [markdown]
# ## extract topics of each comments and save it to csv

# %%
comment_topics = []
for doc_term in doc_term_matrix:
    topic = ldamodel[doc_term]
    comment_topics.append(topic)

# %%
comment_topic_df = pd.DataFrame({'article_ids':article_ids,'comment_texts':comment_texts, 'comment_topics': comment_topics})

# %%
comment_topic_df.to_csv('comment_topics.csv')
